# %% [markdown]
# # Here this crawler will extract names of all the universities from a webpage and save the them into a csv file.

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %% [markdown]
# ## **This is a crawler function which reads date from the website given below. The website has the names of most of the universities in the world and we are trying to read that and write all that into a csv file.**

# %% [markdown]
# link: https://www.4icu.org/reviews/index2.htm

# %%
def crawler_function():
    maxpage=27
    names=[]
    
    #using this for loop it iterates over all the pages 
    #present on the website.
    for page in range(2,maxpage+1,1):
        
        #here a new link is generated for all the pages on website
        url="https://www.4icu.org/reviews/index"+str(page)+".htm"
        
        
        #request to get the web page
        source_code=requests.get(url)
        
        #convert source code of web page into text
        plain_text=source_code.text
        
        
        soup=BeautifulSoup(plain_text)
        x=0
        
        
        #loop below basically extracts the 
        #lines having the name of universities
        for link in soup.findAll('a',):#{ 'href'  }):
            l=str(link)
            x=re.search("s/[1-9]+.htm",l)
            if(x):
                names.append(l)        
                
                
    return names

# %% [markdown]
# ## This names variable has a list of names of all the Universities.

# %%
names=crawler_function()

# %%
names[1:20]
# Out:
# ['<a href="/reviews/17715.htm"> Abbottabad University of Science and Technology</a>',
#  '<a href="/reviews/14616.htm"> Abdul Wali Khan University Mardan</a>',
#  '<a href="/reviews/15143.htm"> Abdullah Gül Üniversitesi</a>',
#  '<a href="/reviews/17274.htm"> Abdulrahman Al-Sumait Memorial University</a>',
#  '<a href="/reviews/4763.htm"> Abertay University</a>',
#  '<a href="/reviews/4823.htm"> Aberystwyth University</a>',
#  '<a href="/reviews/17817.htm"> Abhilashi University</a>',
#  '<a href="/reviews/6637.htm"> Abilene Christian University</a>',
#  '<a href="/reviews/17921.htm"> Abourihan Higher Education Institute</a>',
#  '<a href="/reviews/11138.htm"> Abra State Institute of Science and Technology</a>',
#  '<a href="/reviews/16788.htm"> Abraham Baldwin Agricultural College</a>',
#  '<a href="/reviews/14773.htm"> Abu Ali ibn Sino nomidagi Buxoro Davlat Tibbiyot Instituti</a>',
#  '<a href="/reviews/17118.htm"> Abu Dhabi Polytechnic</a>',
#  '<a href="/reviews/4663.htm"> Abu Dhabi University</a>',
#  '<a href="/reviews/3449.htm"> Abubakar Tafawa Balewa University</a>',
#  '<a href="/reviews/3911.htm"> Academia de Muzica Gheorghe Dima</a>',
#  '<a href="/reviews/9255.htm"> Academia de Muzica, Teatru si Arte Plastice</a>',
#  '<a href="/reviews/3362.htm"> Academia de Studii Economice din Moldova</a>',
#  '<a href="/reviews/16562.htm"> Academia Nacional Superior de Orquestra</a>']

# %% [markdown]
# # Now we will do pre-processing

# %%
#remove the uses less parts using re library
def pre_processing(names):
    for i in range(len(names)):
        l=names[i]
        l=re.sub("</a>","",l,1)
        pos=re.search(">",l).start()+1
        l=l[pos:-1].strip()
        names[i]=l
    return names

# %%
names=pre_processing(names)

# %%
names[1:20]
# Out:
# ['Abbottabad University of Science and Technolog',
#  'Abdul Wali Khan University Marda',
#  'Abdullah Gül Üniversites',
#  'Abdulrahman Al-Sumait Memorial Universit',
#  'Abertay Universit',
#  'Aberystwyth Universit',
#  'Abhilashi Universit',
#  'Abilene Christian Universit',
#  'Abourihan Higher Education Institut',
#  'Abra State Institute of Science and Technolog',
#  'Abraham Baldwin Agricultural Colleg',
#  'Abu Ali ibn Sino nomidagi Buxoro Davlat Tibbiyot Institut',
#  'Abu Dhabi Polytechni',
#  'Abu Dhabi Universit',
#  'Abubakar Tafawa Balewa Universit',
#  'Academia de Muzica Gheorghe Dim',
#  'Academia de Muzica, Teatru si Arte Plastic',
#  'Academia de Studii Economice din Moldov',
#  'Academia Nacional Superior de Orquestr']

# %%
names
# Out:
# ['Aarhus Universite',
#  'Abbottabad University of Science and Technolog',
#  'Abdul Wali Khan University Marda',
#  'Abdullah Gül Üniversites',
#  'Abdulrahman Al-Sumait Memorial Universit',
#  'Abertay Universit',
#  'Aberystwyth Universit',
#  'Abhilashi Universit',
#  'Abilene Christian Universit',
#  'Abourihan Higher Education Institut',
#  'Abra State Institute of Science and Technolog',
#  'Abraham Baldwin Agricultural Colleg',
#  'Abu Ali ibn Sino nomidagi Buxoro Davlat Tibbiyot Institut',
#  'Abu Dhabi Polytechni',
#  'Abu Dhabi Universit',
#  'Abubakar Tafawa Balewa Universit',
#  'Academia de Muzica Gheorghe Dim',
#  'Academia de Muzica, Teatru si Arte Plastic',
#  'Academia de Studii Economice din Moldov',
#  'Academia Nacional Superior de Orquestr',
#  'Academia Rerum Civiliu',
#  'Academic City University Colleg',
#  'Académie des Beaux-Arts de Tourna',
#  'Académie Franco-Américaine de Managemen',
#  'Academie voor Hoger Kunst- en Cultuuronderwij',
#  'Academy of Art Universit',
#  'Academy of Education of Kyrgyzsta',
#  'Academy of Public Administration under the aegis of the President of the Republic of Belaru',
#  'Academy of Public Administration under the President of Kazakhsta',
#  'Academy of Public Administration under the President of the Republic of Tajikista',
#  'Academy of the Ministry of Internal Affair',
#  'Acadia Universit',
#  'Ach Medical Universit',
#  'Acharya N.G. Ranga Agricultural Universit',
#  'Achievers University, Ow',
#  'Acibadem Üniversites',
#  'Ada Kent Üniversites',
#  'ADA Universitet',
#  'Adama Science and Technology Universit',
#  'Adamas Universit',
#  'Adams State Universit',
#  'Adana Alparslan Türkes Bilim ve Teknoloji Üniversites',
#  'Addis Ababa Science and Technology Universit',
#  'Addis Ababa Universit',
#  'Adeleke Universit',
#  'Adesh Universit',
#  'Adigrat Universit',
#  'Adi-Keih College of Arts and Social Science',
#  'Adiyaman Üniversites',
#  'Adler Graduate Schoo',
#  'Adler Universit',
#  'Admiral Makarov National University of Shipbuildin',
#  'Admiralty University of Nigeri',
#  'Adrian Colleg',
#  'Advanced Business Colleg',
#  'AdventHealth Universit',
#  'Adventist International Institute of Advanced Studie',
#  'Adventista Teológiai Fõiskol',
#  'Adyghe State Universit',
#  'Aeres Hogeschoo',
#  'Afe Babalola Universit',
#  'Afghan Swiss Medical Institute of Higher Educatio',
#  'Africa Christian Universit',
#  'Africa Renewal Universit',
#  'Africa Research Universit',
#  'African Bible Universit',
#  'African Leadership University, Rwand',
#  'African Methodist Episcopal Universit',
#  'African Rural Universit',
#  'African University College of Communication',
#  'African University of Managemen',
#  'African University of Science and Technolog',
#  'Afyon Kocatepe Üniversites',
#  'Aga Khan Universit',
#  'Agricultural University of Athen',
#  'Agricultural University of Hebe',
#  'Agricultural University of Icelan',
#  'Agricultural University of Plovdi',
#  'Agriculture and Forestry Universit',
#  'Agrocampus Oues',
#  'AgroParisTec',
#  'Ahlobait Institute of Higher Educatio',
#  'Ahmadu Bello Universit',
#  'Ahmedabad Universit',
#  'Ahmet Yesevi Üniversites',
#  'Ahram Canadian Universit',
#  'Ahsanullah University of Science and Technolog',
#  'Ahvaz Jundishapur University of Medical Science',
#  'Aichi Bunkyo Universit',
#  'Aichi Gakuin Universit',
#  'Aichi Gakusen Universit',
#  'Aichi Institute of Technolog',
#  'Aichi Medical Universit',
#  'Aichi Prefectural Universit',
#  'Aichi Prefectural University of Fine Arts and Musi',
#  'Aichi Sangyo Universit',
#  'Aichi Toho Universit',
#  'Aichi Universit',
#  'Aichi University of Educatio',
#  'Aichi University of Technolog',
#  'Aikoku Gakuen Universit',
#  'Ain Shams Universit',
#  'Aino Universit',
#  'Air Force Institute of Technolog',
#  'Air Universit',
#  'Aix-Marseille Universit',
#  'Ajeenkya D.Y. Patil Universit',
#  'Ajman Universit',
#  'Ajou Universit',
#  'AKAD Privathochschule',
#  'Akademia e Studimeve Albanologjik',
#  'Akademia Finansów i Biznesu Vistul',
#  'Akademia Górniczo-Hutnicz',
#  'Akademia Humanistyczno-Ekonomiczna w Lodz',
#  'Akademia Ivoden',
#  'Akademia Leona Kozminskieg',
#  'Akademia Muzyczna im. Feliksa Nowowiejskiego w Bydgoszcz',
#  'Akademia Muzyczna im. Grazyny i Kiejstuta Bacewiczów w Lodz',
#  'Akademia Muzyczna im. Ignacego Jana Paderewskiego w Poznani',
#  'Akademia Muzyczna im. Karola Lipinskiego we Wroclawi',
#  'Akademia Muzyczna im. Karola Szymanowskiego w Katowicac',
#  'Akademia Muzyczna im. Stanislawa Moniuszki w Gdansk',
#  'Akademia Muzyczna w Krakowi',
#  'Akademia Pedagogiki Specjalnej im. Marii Grzegorzewskie',
#  'Akademia Polonijna w Czestochowi',
#  'Akademia Pomorska w Slupsk',
#  'Akademia Sztuk Pieknych im. Eugeniusza Gepperta we Wroclawi',
#  'Akademia Sztuk Pieknych im. Jana Matejki w Krakowi',
#  'Akademia Sztuk Pieknych im. Wladyslawa Strzeminskiego w Lodz',
#  'Akademia Sztuk Pieknych w Gdansk',
#  'Akademia Sztuk Pieknych w Katowicac',
#  'Akademia Sztuk Pieknych w Warszawi',
#  'Akademia Sztuk Teatralnych im. Stanislawa Wyspianskiego w Krakowi',
#  'Akademia Techniczno-Humanistyczn',
#  'Akademia Wychowania Fizycznego i Sportu im. Jedrzeja Sniadeckieg',
#  'Akademia Wychowania Fizycznego im. Bronislawa Czecha w Krakowi',
#  'Akademia Wychowania Fizycznego im. Eugeniusza Piaseckiego w Poznani',
#  'Akademia Wychowania Fizycznego Józefa Pilsudskiego w Warszawi',
#  'Akademia Wychowania Fizycznego we Wroclawi',
#  'Akademie der Bildenden Künste Münche',
#  'Akademie der Bildenden Künste Nürnber',
#  'Akademie der Bildenden Künste Wie',
#  'Akademie výtvarných umení v Praz',
#  'Akademii Sztuki w Szczecini',
#  'Akal Universit',
#  'AKCENT Colleg',
#  'Akdeniz Üniversites',
#  'Akita International Universit',
#  'Akita Prefectural Universit',
#  'Akita Universit',
#  'Akita University of Nursing and Welfar',
#  'Akobo Heritage and Memorial Universit',
#  'AKS Universit',
#  'Aksum Universit',
#  'Aktobe Regional State Universit',
#  'Al Ain Universit',
#  'Al Alamein International Universit',
#  'Al al-Bayt Universit',
#  'Al Azhar University-Gaz',
#  'Al Baha Universit',
#  'Al Fashir Universit',
#  'Al Ghurair Universit',
#  'Al Imam Al-Ouzai Universit',
#  'Al Iraqia Universit',
#  'Al Mustafa International Universit',
#  'Al Muthanna Universit',
#  'Al Nahrain Universit',
#  'Al Rasheed International Private University for Science and Technolog',
#  'Al Sharqiyah Universit',
#  'Al Yamamah Universit',
#  'Al Zaiem Al Azhari Universit',
#  'Alabama A&amp;M Universit',
#  'Alabama State Universit',
#  'Alagappa Universit',
#  'Al-Ahgaff Universit',
#  'Al-Ahliyya Amman Universit',
#  'Alakh Prakash Goyal Shimla Universit',
#  'Alanus Hochschule für Kunst und Gesellschaf',
#  'Alanya Alaaddin Keykubat Üniversites',
#  'Alanya Hamdullah Emin Pasa Üniversites',
#  'Alaska Bible Colleg',
#  'Alaska Pacific Universit',
#  'Ala-Too Uluslararasi Üniversites',
#  'Al-Azhar Universit',
#  "Al-Balqa' Applied Universit",
#  'Albaydaa Universit',
#  'Albert-Ludwigs-Universität Freibur',
#  'Albion Colleg',
#  'Alborz Institute of Higher Educatio',
#  'Alcorn State Universit',
#  'Aldersgate Colleg',
#  'Alderson Broaddus Universit',
#  'Al-Eman Universit',
#  'Aletheia Universit',
#  'Alex Ekwueme Federal University, Ndufu-Alik',
#  'Alexander American University School Of Medicin',
#  'Alexander Colleg',
#  'Alfa BK Univerzite',
#  'Al-Falah Universit',
#  'Al-Farabi Kazakh National Universit',
#  'Alfred Nobel Universit',
#  'Alfred State Colleg',
#  'Al-Furat Universit',
#  'Algoma Universit',
#  'Al-Hadra University of Humanities and Applied Science',
#  'Al-Hamd Islamic Universit',
#  'Al-Hussein Bin Talal Universit',
#  'Ali Institute of Educatio',
#  'Aliah Universit',
#  'Alice Lloyd Colleg',
#  'Alice Salomon Hochschule Berli',
#  'Al-Imam Muhammad Ibn Saud Islamic Universit',
#  'Al-Jafra Universit',
#  'Aljazeera Universit',
#  'Al-Karkh University of Scienc',
#  'All India Institute of Medical Sciences Bhopa',
#  'All India Institute of Medical Sciences Bhubaneswa',
#  'All India Institute of Medical Sciences Delh',
#  'All India Institute of Medical Sciences Jodhpu',
#  'All India Institute of Medical Sciences Patn',
#  'All India Institute of Medical Sciences Raipu',
#  'All Nations University Colleg',
#  'All Saints Universit',
#  'Allahabad State Universit',
#  'Allameh Mohaddes Nouri Universit',
#  "Allameh Tabataba'i Universit",
#  'Allen Universit',
#  'Allensbach Hochschule Konstan',
#  'Alliance Universit',
#  'Alliant International Universit',
#  'Alma Mater Europae',
#  'Al-Madinah International Universit',
#  'Almaty Academy of Economics and Statistic',
#  'Almaty Universit',
#  'Almaty University of Power Engineering and Telecommunication',
#  'AlMughtaribeen Universit',
#  'Alpen-Adria-Universität Klagenfur',
#  'Al-Qasim Green Universit',
#  'Al-Quds Universit',
#  'Al-Rafaq National Universit',
#  'Al-Saeeda Universit',
#  'Alsalam Universit',
#  'Al-Sham Private Universit',
#  'Al-Tahadi National Medical Universit',
#  'Altai State Academy of Educatio',
#  'Altai State Universit',
#  'Al-taqwa Institute of Higher Educatio',
#  'Altinbas Üniversites',
#  'Alvernia Universit',
#  'Alverno Colleg',
#  'Al-Wataniya Private Universit',
#  'Alytaus kolegij',
#  'Alzahra Universit',
#  'Al-Zaytoonah University of Jorda',
#  'AMA Computer Universit',
#  'AMA International University Bahrai',
#  'Ambassador International Universit',
#  'Ambedkar University Delh',
#  'Amberton Universit',
#  'Ambo Universit',
#  'Ambrose Universit',
#  'American Baptist Colleg',
#  'American Colleg',
#  'American International Colleg',
#  'American International School of Medicin',
#  'American International University West Afric',
#  'American International University-Banglades',
#  'American Jewish Universit',
#  'American University in Bulgari',
#  'American University in Duba',
#  'American University in North Afric',
#  'American University in the Emirate',
#  'American University of Barbado',
#  'American University of Beiru',
#  'American University of Central Asi',
#  'American University of Integrative Science',
#  'American University of Malt',
#  'American University of Phnom Pen',
#  'American University of Puerto Ric',
#  'American University of Ras Al Khaima',
#  'American University of Science and Technolog',
#  'American University of Sharja',
#  'American University of the Caribbea',
#  'American University of the Caribbean - School of Medicin',
#  'Americki Univerzitet u Bosni i Hercegovin',
#  'Amherst Colleg',
#  'Amirkabir University of Technolog',
#  'Amity Universit',
#  'Amman Arab Universit',
#  'Ammon Applied University Colleg',
#  'Amran Universit',
#  'Amref International Universit',
#  'Amrita Vishwa Vidyapeetha',
#  'Amsterdamse Hogeschool voor de Kunste',
#  'Amur State Universit',
#  'Amur State University of Humanities and Pedagog',
#  'Anadolu Üniversites',
#  'Anania Shirakatsi University of International Relation',
#  'Anchor University, Lago',
#  'Anderson Universit',
#  'Andhra Universit',
#  'Andijon Davlat Universitet',
#  'Andijon Mashinasozlik Institut',
#  "Andijon Qishloq Xo'jalik Institut",
#  'Andrássy Universität Budapes',
#  'Andrews Universit',
#  'Angel Kanchev University of Rus',
#  'Angeles University Foundatio',
#  'Angkor Khemara Universit',
#  'Anglia Ruskin Universit',
#  'Anglican University College of Technolog',
#  'Anglo-americká vysoká \x9akol',
#  'Anhui Agricultural Universit',
#  'Anhui Jianzhu Universit',
#  'Anhui Medical Universit',
#  'Anhui Normal Universit',
#  'Anhui Polytechnic Universit',
#  'Anhui Sanlian Universit',
#  'Anhui Science and Technology Universit',
#  'Anhui Universit',
#  'Anhui University of Chinese Medicin',
#  'Anhui University of Finance and Economic',
#  'Anhui University of Technolog',
#  'Anhui Xinhua Universit',
#  'Anka Teknoloji Üniversites',
#  'Ankang Universit',
#  'Ankara Sosyal Bilimler Üniversites',
#  'Ankara Üniversites',
#  'Ankara Yildirim Beyazit Üniversites',
#  'Ankole Western Universit',
#  'Anna Maria Colleg',
#  'Anna Universit',
#  'An-Najah National Universit',
#  'Annamalai Universit',
#  'Anqing Normal Universit',
#  'Ansal Universit',
#  'Anshan Normal Universit',
#  'Anshun Universit',
#  'Antalya Akev Üniversites',
#  'Antalya Bilim Üniversites',
#  'Antioch Universit',
#  'Antioch University New Englan',
#  'Antioch University Seattl',
#  'Anton Bruckner Privatuniversitä',
#  'Anton de Kom Universiteit van Surinam',
#  'Antwerp Management Schoo',
#  'Anyang Institute of Technolog',
#  'Anyang Normal Universit',
#  'Anyang Universit',
#  'Aomori Chuo Gakuin Universit',
#  'Aomori Public Universit',
#  'Aomori Universit',
#  'Aoyama Gakuin Universit',
#  'AP Hogeschool Antwerpe',
#  'Apeejay Stya Universit',
#  'Apex Professional Universit',
#  'Apex Universit',
#  'APJ Abdul Kalam Technological Universit',
#  'Appalachian Bible Colleg',
#  'Appalachian College of Pharmac',
#  'Appalachian State Universit',
#  'Applied Science Private Universit',
#  'Applied Science Universit',
#  'Aquinas Colleg',
#  'Aquinas College, Tennesse',
#  'Aquinas University of Legazp',
#  'Arab Academy for Science, Technology and Maritime Transpor',
#  'Arab International Universit',
#  'Arab Open University Lebano',
#  'Arab University of Science and Technolog',
#  'Arak Universit',
#  'Arak University of Medical Science',
#  'Arak University of Technolog',
#  'Arba Minch Universit',
#  'Architectural Institute in Pragu',
#  'Ardhi Universit',
#  'Arellano Universit',
#  'Arish Universit',
#  'Aristotle University of Thessalonik',
#  'Arizona Christian Universit',
#  'Arizona State Universit',
#  'Arka Jain Universit',
#  'Arkansas Baptist Colleg',
#  'Arkansas State Universit',
#  'Arkansas Tech Universit',
#  'Arkin Yaratici Sanatlar ve Tasarim Üniversites',
#  'Arkitektskolen Aarhu',
#  'Arkitektur- og designhøgskolen i Osl',
#  'Arlington Baptist Universit',
#  'Armavir State Pedagogical Universit',
#  'Armenian Medical Institut',
#  'Armenian National Agrarian Universit',
#  'Armenian State Institute of Physical Cultur',
#  'Armenian State Pedagogical Universit',
#  'Armenian State University of Economic',
#  'Arni Universit',
#  'Arrupe Jesuit Universit',
#  'Art and Design Institu',
#  'Art University of Isfaha',
#  'Arte A.C',
#  'Arteveldehogeschoo',
#  'ArtHouse - \x8aola za risanje in slikanj',
#  'Arthur Jarvis Universit',
#  'Arts University Bournemout',
#  'Arts, Sciences and Technology University in Lebano',
#  'Arts² - École supérieure des Art',
#  'Artsakh State Universit',
#  'Arunachal University of Studie',
#  'Arunodaya Universit',
#  'Asahi Universit',
#  'Asahikawa Medical Universit',
#  'Asahikawa Universit',
#  'Asbury Universit',
#  'Ashesi Universit',
#  'Ashikaga Institute of Technolog',
#  'Ashiya Universit',
#  'Ashland Universit',
#  'Ashna Institute of Higher Educatio',
#  'Ashoka Universit',
#  'Asia e Universit',
#  'Asia Pacific Colleg',
#  'Asia Universit',
#  'Asia University, Taiwa',
#  'Asian Institute of Journalism and Communicatio',
#  'Asian Institute of Managemen',
#  'Asian Institute of Technolog',
#  'Asian Medical Institut',
#  'Asian Social Institut',
#  'Asian University for Wome',
#  'Asian University of Banglades',
#  'Asia-Pacific International Universit',
#  'Asmara College of Health Science',
#  'Asmarya University for Islamic Science',
#  'Assam Agricultural Universit',
#  'Assam Down Town Universit',
#  'Assam Rajiv Gandhi University of Cooperative Managemen',
#  'Assam Science and Technology Universit',
#  'Assam Universit',
#  "Assam Women's Universit",
#  'Assiut Universit',
#  'Assosa Universit',
#  'Assumption Colleg',
#  'Assumption College San Lorenz',
#  'Assumption Universit',
#  'Astana Medical Universit',
#  'Astana Universit',
#  'Aswan Universit',
#  'Atal Bihari Vajpayee Hindi Vishwavidyalay',
#  'Atal Bihari Vajpayee Vishwavidyalay',
#  'Atatürk Üniversites',
#  'Ateneo de Davao Universit',
#  'Ateneo de Manila Universit',
#  'Ateneo de Naga Universit',
#  'Ateneo de Zamboanga Universit',
#  'Athens School of Fine Art',
#  'Athens State Universit',
#  'Athens University of Economics and Busines',
#  'Athlone Institute of Technolog',
#  'Atilim Üniversites',
#  'Atish Dipankar University of Science and Technolog',
#  'Atlanta Metropolitan State Colleg',
#  'Atlantis Colleg',
#  'Atmiya Universit',
#  'Atomi Universit',
#  'Atyrau Institute of Engineering and Humanitie',
#  'Atyrau State Universit',
#  'Auburn Universit',
#  'Auburn University at Montgomer',
#  'Auckland University of Technolog',
#  'Audencia Business Schoo',
#  'Augsburg Universit',
#  'Augusta Universit',
#  'Augustana Colleg',
#  'Augustana Universit',
#  'Augustana-Hochschul',
#  'AURO Universit',
#  'Aurora Colleg',
#  'Aurora State College of Technolog',
#  'Austin Colleg',
#  'Australian Catholic Universit',
#  'Australian College of Kuwai',
#  'Australian National Universit',
#  'Avance International Universit',
#  'AVANS Hogeschoo',
#  'Avantika Universit',
#  'Avarga Institut',
#  'Ave Maria Universit',
#  'Averett Universit',
#  'Avicenna Universit',
#  'Avignon Universit',
#  'Avila Universit',
#  'Avinashilingam Universit',
#  'Avrasya Üniversites',
#  'Awadhesh Pratap Singh Universit',
#  'Aydin Adnan Menderes Üniversites',
#  'Azabu Universit',
#  'Azerbaycan Diller Universitet',
#  'Azerbaycan Dövlet Aqrar Universitet',
#  'Azerbaycan Dövlet Beden Terbiyesi ve Idman Akademiyas',
#  'Azerbaycan Dövlet Deniz Akademiyas',
#  'Azerbaycan Dövlet Medeniyyet ve Incesenet Universitet',
#  'Azerbaycan Dövlet Neft ve Senaye Universitet',
#  'Azerbaycan Dövlet Pedaqoji Universitet',
#  'Azerbaycan Emek ve Sosial Münasibetler Akademiyas',
#  'Azerbaycan Kooperasiya Universitet',
#  'Azerbaycan Memarliq ve Insaat Universitet',
#  'Azerbaycan Milli Konservatoriyas',
#  'Azerbaycan Texniki Universitet',
#  'Azerbaycan Texnologiya Universitet',
#  'Azerbaycan Tibb Universitet',
#  'Azerbaycan Turizm ve Menecment Universitet',
#  'Azhar Higher Education Institut',
#  'Azim Premji Universit',
#  'B.S. Abdur Rahman Crescent Institute of Science and Technolog',
#  'Baba Ghulam Shah Badhshah Universit',
#  'Baba Mastnath Universit',
#  'Babol University of Medical Science',
#  'Babson Colleg',
#  'Babu Banarasi Das Universit',
#  'Bacone Colleg',
#  'Badakhshan Universit',
#  'Baddi University of Emerging Sciences and Technologie',
#  'Badr University in Cair',
#  'Baekseok Universit',
#  'Baghlan Universit',
#  'Bago Universit',
#  'Bahauddin Zakariya Universit',
#  'Bahçesehir Kibris Üniversites',
#  'Bahçesehir Üniversites',
#  'Bahir Dar Universit',
#  'BAHRA Universit',
#  'Bahrain Institute for Banking and Financ',
#  'Bahria Universit',
#  'Baicheng Normal Universit',
#  'Baikal State Universit',
#  'Baiko Gakuin Universit',
#  'Baker Colleg',
#  'Baker Universit',
#  'Baki Ali Neft Mekteb',
#  'Baki Avrasiya Universitet',
#  'Baki Biznes Universitet',
#  'Baki Dövlet Universitet',
#  'Baki Islam Universitet',
#  'Baki Muhendislik Universitet',
#  'Baki Musiqi Akademiyas',
#  'Baki Qizlar Universitet',
#  'Baki Slavyan Universitet',
#  'Bakirçay Üniversites',
#  'Baldwin Wallace Universit',
#  'Balkh Universit',
#  'Ball State Universit',
#  'Balochistan University of Engineering and Technolog',
#  'Balochistan University of Information Technology, Engineering and Management Science',
#  'Bam Universit',
#  'Bamenda University of Science and Technolog',
#  'Bamiyan Universit',
#  'Banasthali Vidyapit',
#  'Banda University of Agriculture and Technolog',
#  'Bandarban Universit',
#  'Bandirma Onyedi Eylül Üniversites',
#  'Bangabandhu Sheikh Mujib Medical Universit',
#  'Bangabandhu Sheikh Mujibur Rahman Agricultural Universit',
#  'Bangabandhu Sheikh Mujibur Rahman Maritime Universit',
#  'Bangabandhu Sheikh Mujibur Rahman Science and Technology Universit',
#  'Bangalore Universit',
#  'Bangamata Sheikh Fojilatunnesa Mujib Science and Technology Universit',
#  'Bangkok Suvarnabhumi Universit',
#  'Bangkok Universit',
#  'Bangladesh Agricultural Universit',
#  'Bangladesh University of Professional',
#  'Bangladesh University of Textile',
#  'Bangor Universit',
#  'Bani Walid Universit',
#  'Bank of Georgia Universit',
#  'Bank-moliya Akademiyas',
#  'Baoshan Universit',
#  'Baptist Bible Colleg',
#  'Baptist Memorial College of Health Science',
#  'Baptist University of the America',
#  'Baqai Medical Universit',
#  'Barclay Colleg',
#  "Bard College at Simon's Roc",
#  'Bard College Berli',
#  'Bareilly International Universit',
#  'Bar-Ilan Universit',
#  'Barkatullah Universit',
#  'Barry Universit',
#  'Bashkir State Universit',
#  'Baskent Üniversites',
#  'Basra University of Oil an Ga',
#  'Bastar Vishwavidyalay',
#  'Bastyr Universit',
#  'Bates Colleg',
#  'Batumi Navigation Teaching Universit',
#  'BAU International University, Batum',
#  'Bauhaus-Universität Weima',
#  'Bauman Moscow State Technical Universit',
#  'Bay Path Universit',
#  'Bay State Colleg',
#  'Bayan Universit',
#  'Baylor College of Medicin',
#  'Baylor Universit',
#  'Baze Universit',
#  'BBS School of Managemen',
#  'Beacon Colleg',
#  'Beaconhouse National Universit',
#  'Becker Colleg',
#  'Beckmans Designhögskol',
#  'Behbahan Khatam Alanbia University of Technolog',
#  'Beihua Universit',
#  'Beijing City Universit',
#  'Beijing Dance Academ',
#  'Beijing Electronic Science and Technology Institut',
#  'Beijing Film Academ',
#  'Beijing Foreign Studies Universit',
#  'Beijing Forestry Universit',
#  'Beijing Information Science and Technology Universit',
#  'Beijing Institute of Fashion Technolog',
#  'Beijing Institute of Graphic Communicatio',
#  'Beijing Institute of Petrochemical Technolog',
#  'Beijing Institute of Technolog',
#  'Beijing International Studies Universit',
#  'Beijing Jiaotong Universit',
#  'Beijing Language and Culture Universit',
#  'Beijing Technology and Business Universit',
#  'Beijing University of Agricultur',
#  'Beijing Wuzi Universit',
#  'Beirut Arab Universit',
#  'Beirut Islamic Universit',
#  'Belarusian National Technical Universit',
#  'Belarusian State Academy of Art',
#  'Belarusian State Academy of Communication',
#  'Belarusian State Academy of Musi',
#  'Belarusian State Agrarian Technical Universit',
#  'Belarusian State Agricultural Academ',
#  'Belarusian State Economic Universit',
#  'Belarusian State Medical Universit',
#  'Belarusian State Pedagogical Universit',
#  'Belarusian State Universit',
#  'Belarusian State University of Culture and Art',
#  'Belarusian State University of Informatics and Radioelectronic',
#  'Belarusian-Russian Universit',
#  'Belgorod State Technological Universit',
#  'Bellarmine Universit',
#  'Bellevue Universit',
#  'Bellin Colleg',
#  'Belmont Universit',
#  'Beloit Colleg',
#  'Beltei International Universit',
#  'Benawa Institute of Higher Educatio',
#  'Benazir Bhutto Shaheed University Lyar',
#  'Benazir Bhutto Shaheed University of Technology and Skill Developmen',
#  'Benedict Colleg',
#  'Benedictine Colleg',
#  'Benedictine Universit',
#  'Benemerita Universidad Autonoma de Puebl',
#  'Bengaluru North Universit',
#  'Bengbu Medical Colleg',
#  'Bengbu Universit',
#  'Benguet State Universit',
#  'Ben-Gurion University of the Nege',
#  'Benjamin Franklin Institute of Technolog',
#  'Bennett Universit',
#  'Bennington Colleg',
#  'Benson Idahosa Universit',
#  'Bentley Universit',
#  'Beppu Universit',
#  'Berdyansk University of Management and Busines',
#  'Bergische Universität Wupperta',
#  'Berhampur Universit',
#  'Berkeley Colleg',
#  'Berry Colleg',
#  'Bertha von Suttner Privatuniversitä',
#  'Bethany Colleg',
#  'Bethany College, Kansa',
#  'Bethel Colleg',
#  'Bethel Universit',
#  'Bethel University, Tennesse',
#  'Bethel University, Zambi',
#  'Bethesda Universit',
#  'Bethlehem Universit',
#  'Bethune-Cookman Universit',
#  'Beulah Heights Universit',
#  'Beuth Hochschule für Technik Berli',
#  'Beykent Üniversites',
#  'Beykoz Üniversites',
#  'Bezmiâlem Vakif Üniversites',
#  'Bhagat Phool Singh Mahila Vishwavidyalay',
#  'Bhagwant Universit',
#  'Bhakta Kavi Narsinh Mehta Universit',
#  'Bharath Institute of Higher Education and Researc',
#  'Bharathiar Universit',
#  'Bharathidasan Universit',
#  'Bharati Vidyapeeth Deemed Universit',
#  'Bhartiya Skill Development Universit',
#  'Bhatkhande Music Institut',
#  'Bhiksu University of Sri Lank',
#  'Bhupal Nobles Universit',
#  'Bicol Universit',
#  'Bidhan Chandra Krishi Vishwavidyalay',
#  'Bielska Wyzsza Szkola im. Józefa Tyszkiewicz',
#  'Bihar Agricultural Universit',
#  'Biju Patnaik University of Technolog',
#  'Bila Tserkva National Agrarian Universit',
#  'Bilad Al Sham Universit',
#  'Biliran Province State Universit',
#  'Bilkent Üniversites',
#  'Bindura University of Science Educatio',
#  'Bingham Universit',
#  'Binghamton University, State University of New Yor',
#  'Binod Bihari Mahto Koyalanchal Universit',
#  'Binzhou Universit',
#  'Birjand University of Technolog',
#  'Birkbeck, University of Londo',
#  'Birla Institute of Technolog',
#  'Birla Institute of Technology and Scienc',
#  'Birmingham City Universit',
#  'Birmingham-Southern Colleg',
#  'Biruni Üniversites',
#  'Birzeit Universit',
#  'Bishkek Academy of Finance and Economic',
#  'Bishkek Humanities Universit',
#  'Bishop Grosseteste Universit',
#  'Bishop Stuart Universit',
#  "Bishop's Universit",
#  'Bitlis Eren Üniversites',
#  'Biwako Seikei Sport Colleg',
#  'Biznesa augstskola Turib',
#  'Black Hills State Universit',
#  'Black Sea National Universit',
#  'Blackburn Colleg',
#  'Blagoveshchensk State Pedagogical Universit',
#  'Blantyre International Universit',
#  'BLDE Universit',
#  'Blekinge Tekniska Högskol',
#  'Blessing University of Excellenc',
#  'Blessing-Rieman College of Nursing and Health Science',
#  'Bloomsburg University of Pennsylvani',
#  'Blue Mountain Colleg',
#  'BlueCrest Colleg',
#  'Bluefield Colleg',
#  'Bluefield State Colleg',
#  'Bluefields Indian and Caribbean Universit',
#  'Bluffton Universit',
#  'BML Munjal Universit',
#  'Bob Jones Universit',
#  'Bodoland Universit',
#  'Bogaziçi Üniversites',
#  'Bohai Universit',
#  'Bohol Island State Universit',
#  'Boise Bible Colleg',
#  'Bolan University of Medical and Health Science',
#  'Bolu Abant Izzet Baysal Üniversites',
#  'Bond Universit',
#  'Bordeaux IN',
#  'Borno State Universit',
#  'Borys Grinchenko Kyiv Universit',
#  'Bost Universit',
#  'Boston Graduate School of Psychoanalysi',
#  'Botswana Accountancy Colleg',
#  'Botswana International University of Science and Technolog',
#  'Bournemouth Universit',
#  'Bowdoin Colleg',
#  'Bowling Green State Universit',
#  'BPP Universit',
#  'Bradley Universit',
#  'Brainware Universit',
#  'Brand University of Applied Science',
#  'Brandenburgische Technische Universität Cottbus-Senftenber',
#  'Brandon Universit',
#  'Bratislavská medzinárodná \x9akola liberálnych \x9atúdi',
#  'Breda University of Applied Science',
#  'Brenau Universit',
#  'Brescia Universit',
#  'Brest Business Schoo',
#  'Brest State Technical Universit',
#  'Brest State Universit',
#  'Brewton-Parker Colleg',
#  'Briar Cliff Universit',
#  'Bridgewater Colleg',
#  'Brigham Young Universit',
#  'Brigham Young University-Hawai',
#  'Brigham Young University-Idah',
#  'Bright Star Universit',
#  'Britannia Universit',
#  'British Columbia Institute of Technolog',
#  'Brock Universit',
#  'Brook Besor Universit',
#  'Brown Universit',
#  'Brunel University Londo',
#  'Bryan Colleg',
#  'Bryansk State Technical Universit',
#  'Bryant and Stratton Colleg',
#  'Bryant Universit',
#  'Bryn Athyn Colleg',
#  'Bryn Mawr Colleg',
#  'BSP Business School Berli',
#  'Bu-Ali Sina Universit',
#  'Buckinghamshire New Universit',
#  'Bucknell Universit',
#  'Budapesti Corvinus Egyete',
#  'Budapesti Metropolitan Egyete',
#  'Budapesti Muszaki és Gazdaságtudományi Egyete',
#  'Buddhist and Pali Universit',
#  'Buena Vista Universit',
#  'Bujumbura International Universit',
#  'Bukkyo Universit',
#  'Bukovinian State Medical Universit',
#  'Bule Hora Universit',
#  'Bunka Fashion Graduate Universit',
#  'Bunka Gakuen Universit',
#  'Bunkyo Gakuin Universit',
#  'Bunkyo Universit',
#  'Bunri University of Hospitalit',
#  'Bunsei University of Ar',
#  'Burapha Universit',
#  'Burdur Mehmet Akif Ersoy Üniversites',
#  'Burg Giebichenstein Kunsthochschule Hall',
#  'Burgas Free Universit',
#  'Burman Universit',
#  'Bursa Teknik Üniversites',
#  'Buryat State Academy of Agricultur',
#  'Busan National University of Educatio',
#  'Busan Presbyterian Universit',
#  'Bushnell Universit',
#  'Business and Technology Universit',
#  'Busitema Universit',
#  'Busoga Universit',
#  'Butler Universit',
#  'Buxoro Davlat Universitet',
#  'Buxoro muhandislik-texnologiya institut',
#  'C.D.A. Colleg',
#  'C.U. Shah Universit',
#  'Cabrini Universit',
#  'Çag Üniversites',
#  'Cairn Universit',
#  'Cairo Universit',
#  'Calumet College of St. Josep',
#  'Calvary Universit',
#  'Calvin Universit',
#  'Camarines Norte State Colleg',
#  'Camarines Sur Polytechnic College',
#  'Cambridge Colleg',
#  'CamEd Business Schoo',
#  'Cameron Universit',
#  'Campbellsville Universit',
#  'Campion College at the University of Regin',
#  'CAMPUS 02 Fachhochschule der Wirtschaf',
#  'Can Tho Universit',
#  'Canadian Mennonite Universit',
#  'Canadian University of Banglades',
#  'Canadian University of Duba',
#  'Çanakkale Onsekiz Mart Üniversites',
#  'Çankaya Üniversites',
#  'Çankiri Karatekin Üniversites',
#  'Canterbury Christ Church Universit',
#  'Cape Breton Universit',
#  'Cape Peninsula University of Technolog',
#  'Capital Medical Universit',
#  'Capital Normal Universit',
#  'Capital Universit',
#  'Capital University of Economics and Busines',
#  'Capital University of Physical Education and Sport',
#  'Capital University of Science and Technolog',
#  'Capitol Technology Universit',
#  'Capitol Universit',
#  'Caraga State Universit',
#  'Cardiff Metropolitan Universit',
#  'Cardiff Universit',
#  'Cardinal Stritch Universit',
#  'Career Point Universit',
#  'Caribbean Nazarene Colleg',
#  'Caribbean Universit',
#  'Caritas Universit',
#  'Carleton Colleg',
#  'Carleton Universit',
#  'Carlos Albizu Universit',
#  'Carlow Universit',
#  'Carnegie Mellon Universit',
#  'Carnegie Mellon University in Qata',
#  'Carolina Universit',
#  'Carroll Colleg',
#  'Carroll Universit',
#  'Carson-Newman Universit',
#  'Carthage Colleg',
#  'Casa Colleg',
#  'Caspian Universit',
#  'Castleton Universit',
#  'Catholic Institute of Business and Technolog',
#  'Catholic University College of Ghan',
#  'Catholic University in Erbi',
#  'Catholic University of Cameroo',
#  'Catholic University of Daeg',
#  'Catholic University of Daejeo',
#  'Catholic University of Pusa',
#  'Catholic University of Rwand',
#  'Catholic University of Zimbabw',
#  'Caucasus International Universit',
#  'Cavendish University Ugand',
#  'Cavendish University Zambi',
#  'Cazenovia Colleg',
#  'CCN University of Science and Technolog',
#  "Cebu Doctors' Universit",
#  'Cebu Normal Universit',
#  'Cebu Technological Universit',
#  'CECOS Universit',
#  'Cedar Crest Colleg',
#  'Cedarville Universit',
#  'Centenary College of Louisian',
#  'Central Agricultural Universit',
#  'Central America Health Sciences University, Belize Medical Colleg',
#  'Central China Normal Universit',
#  'Central Christian College of the Bibl',
#  'Central Conservatory of Musi',
#  'Central Institute of Fisheries Educatio',
#  'Central Kazakhstan Academ',
#  'Central Luzon State Universit',
#  'Central Methodist Universit',
#  'Central Michigan Universit',
#  'Central Mindanao Universit',
#  'Central Penn Colleg',
#  'Central Philippine Adventist Colleg',
#  'Central Philippine Universit',
#  'Central Queensland Universit',
#  'Central South Universit',
#  'Central South University of Forestry and Technolog',
#  'Central State Universit',
#  'Central Universit',
#  'Central University of Finance and Economic',
#  'Central University of Gujara',
#  'Central University of Haryan',
#  'Central University of Himachal Prades',
#  'Central University of Jamm',
#  'Central University of Jharkhan',
#  'Central University of Karnatak',
#  'Central University of Keral',
#  'Central University of Odish',
#  'Central University of Punja',
#  'Central University of Rajastha',
#  'Central University of South Biha',
#  'Central University of Tamil Nad',
#  'Central University of Technolog',
#  'Central University of Tibetan Studie',
#  'Central Washington Universit',
#  'Centrale Lill',
#  'CentraleSupéle',
#  'Centre Colleg',
#  'Centro de Estudios Avanzados de Puerto Rico y El Carib',
#  'Centro de Estudios Superiores de Diseño de Monterrey S.C',
#  'Centro de Estudios Superiores de San Ángel S.C',
#  'Centro de Estudios Universitario',
#  'Centro de Estudios Universitarios Xochicalc',
#  'Centro de Investigación y Docencia Económica',
#  'Centro Escolar Universit',
#  'Centro Universitario de Integración Humanística A.C',
#  'Centurion University of Technology and Managemen',
#  "CESI École d'Ingénieur",
#  'Ceská zemedelská univerzita v Praz',
#  'Ceské vysoké ucení technické v Praz',
#  'CEVRO Institu',
#  'CHA Universit',
#  'Chabahar Maritime Universit',
#  'Chadron State Colleg',
#  'Chalermkarnchana Universit',
#  'Chalimbana Universit',
#  'Chalmers tekniska högskol',
#  'Chaminade University of Honolul',
#  'Champlain Colleg',
#  'Chanakya National Law Universit',
#  'Chandigarh Universit',
#  'Chang Gung Universit',
#  'Chang Gung University of Science and Technolog',
#  'Chang Jung Christian Universit',
#  "Chang'an Universit",
#  'Changchun Architecture and Civil Engineering Colleg',
#  'Changchun Institute of Technolog',
#  'Changchun University of Chinese Medicin',
#  'Changchun University of Science and Technolog',
#  'Changchun University of Science and Technolog',
#  'Changchun University of Technolog',
#  'Changji Universit',
#  'Changsha Medical Universit',
#  'Changsha Universit',
#  'Changsha University of Science and Technolog',
#  'Changshu Institute of Technolog',
#  'Changwon National Universit',
#  'Changzhi Medical Colleg',
#  'Changzhi Universit',
#  'Changzhou Institute of Technolog',
#  'Changzhou Universit',
#  'Chaohu Universit',
#  'Chaopraya Universit',
#  'Chaoyang University of Technolog',
#  'Charles Darwin Universit',
#  'Charleston Southern Universit',
#  'Charmo Universit',
#  'Charotar University of Science and Technolog',
#  'Chatham Universit',
#  'Chaudhary Bansi Lal Universit',
#  'Chaudhary Charan Singh Haryana Agricultural Universit',
#  ...]

# %%
len(names) #total number of all the universities
# Out:
# 9568

# %% [markdown]
# # Here we write all the names present in this "names[ ]" into a csv file.
# # Open the csv file generate in excel. it is saved in same location as this file.

# %%
#convert list into pandas dataframe and save into a csv file.
df=pd.DataFrame(names)
df.to_csv("Names_of_all_the_universities.csv")
